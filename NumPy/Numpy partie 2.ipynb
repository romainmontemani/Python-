# %% [markdown]
# **Numpy**

# %%
import numpy as np

# %%
arr=np.array([-3,-4,1,4,5])
print('mean', arr.mean())
print('min', arr.min())
print('max', arr.max())
print('median', np.median(arr))
# Out:
# mean 0.6
# min -4
# max 5
# median 1.0

# %%
arr[3]
# Out:
# np.int64(4)

# %%
arr[2]
# Out:
# np.int64(1)

# %%
arr[0]
# Out:
# np.int64(-3)

# %%
arr[1:3]
# Out:
# array([-4,  1])

# %%
arr[:3]
# Out:
# array([-3, -4,  1])

# %%
arr[1:]
# Out:
# array([-4,  1,  4,  5])

# %%
arr[::2]
# Out:
# array([-3,  1,  5])

# %%
arr[::3]
# Out:
# array([-3,  4])

# %%
arr[arr>0]
# Out:
# array([1, 4, 5])

# %%
arr[2]=15
arr
# Out:
# array([-3, -4, 15,  4,  5])

# %%
arr[arr<0]=0
arr
# Out:
# array([ 0,  0, 15,  4,  5])
