# %% [markdown]
# # **Plotly**

# %%
import plotly.express as px

# %%
# Créer un graphique interactif
fig = px.scatter (
    iris,
    x="sepal_length",
    y="sepal_width",
    color="species", size="petal_length",
    title="Iris Dataset: Sepal Length vs Sepal Width",
    labels=("sepal_length": "Longueur Sepal (cm)", "sepal_width": "Largeur Sepal (cm) "},
    )
fig. show()

# %%
# Charger le dataset flights
import seaborn as sns
import plotly.express as px

flights = sns.load_dataset ("flights")

# Créer un graphique interactif
fig = px.line(
    flights, 
    x="year",
    y="passengers",
    color="month",
    title="Évolution du nombre de passagers par mois (1949-1960)",
    labels={
        "year": "Année",
        "passengers": "Nombre de passagers",
        "month": "Mois",
   } ,
)
    
# Afficher le graphique interactif
fig. show ()

# %%
#Autre exemple
#Charger le dataset gapminder
gapminder = px.data.gapminder ()

#Créer un graphique interactif
ig = px. scatter(
    gapminder,
    x="gdpPercap",
    y="lifeExp" ,
    size="pop",
    color="continent",
    hover_name="country",
    log_x=True,
    range_y=[20, 90],
    animation_frame="year",
    title="Évolution de l'espérance de vie et du PIB par habitant (1952-2007)",
    labels={
        "gapPercap": "PIB par habitant (log)",
        "lifeExp": "Espérance de vie",
        "year": "Année",
        "pop": "Population",
        "continent": "Continent",
    },
height=600,
)
    
#Affiner l'apparence du graphique
ig.update_traces(marker=dict(line=dict(width=1, color="rgba(0, 0, 0, 0.5)")))
ig.update_layout(showlegend=True, legend=dict(orientation="h", yanchor="bottom", y=-0.2, xanchor="center", x=0.5))
                                              
#Afficher le graphique interactif 
fig. show()
