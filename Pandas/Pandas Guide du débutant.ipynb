# %% [markdown]
# **1. Importer et inqstallation du Package**

# %%
#pip install pandas
import pandas as pd

# %% [markdown]
# **2. Création du Data frame**

# %% [markdown]
# **2.1 Création à partir d'un dictionnaire**

# %%
#Création d'un dictionnaire
etudiant = {"Nom" :["Mendong","Zibi","Ekounou","Bastos"],
            "Prenom":["Chloe","Loic","Helene","Nathan"],
            "Notes":[19,18,15,13]}
etudiant
# Out:
# {'Nom': ['Mendong', 'Zibi', 'Ekounou', 'Bastos'],
#  'Prenom': ['Chloe', 'Loic', 'Helene', 'Nathan'],
#  'Notes': [19, 18, 15, 13]}

# %%
#Tansformer le dictionnaire en dataframe
df_etudiant = pd.DataFrame(etudiant)
df_etudiant
# Out:
#        Nom  Prenom  Notes
# 0  Mendong   Chloe     19
# 1     Zibi    Loic     18
# 2  Ekounou  Helene     15
# 3   Bastos  Nathan     13

# %% [markdown]
# **2.2 Création à partir d'un fichier csv/excel**

# %%
#Importation du fichier csv
df=pd.read_csv("credit_risk_dataset.csv", sep=";")
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# ...

# %%
#Importation du fichier excel
df=pd.read_excel("credit_dataset_excel.xlsx")
df
# Out:
#     Id_personne  Age       Nom     Prenom  Revenu Type de domicile  \
# 0             1   40     Akono     Nathan   59000        Locataire
# 1             2   35      Akwa      Aicha   70000     Propriétaire
# 2             3   25    Arnaud      Matin    9600        Locataire
# 3             4   23       Awa      Marie   44000             Pret
# 4             5   24    Dubois   Lachaise   54400             Pret
# 5             6   21    Durand     Bertin    9900        Locataire
# 6             7   44   Ekounou        Eli   77100     Propriétaire
# 7             8   24   Mendong       Zibi   33000        Locataire
# 8             9   24    Moussa     Hamado   24000        Locataire
# 9            10   50  Mvog-ada     Bertin   80000     Propriétaire
# 10           11   22     Mvogo    Melanie   25000        Locataire
# 11           12   21      Neba   Charlène   10000        Locataire
# 12           13   34       Ngo  Stephanie   95000             Pret
# ...

# %% [markdown]
# **2.3 Afficher un dataframe et afficher le type de données et description de colonne**

# %%
#Afficher les 5 premier éléments
df.head(5)
# Out:
#    Id_personne  Age     Nom    Prenom  Revenu Type de domicile Travail  \
# 0            1   40   Akono    Nathan   59000        Locataire     CDI
# 1            2   35    Akwa     Aicha   70000     Propriétaire     CDI
# 2            3   25  Arnaud     Matin    9600        Locataire     CDD
# 3            4   23     Awa     Marie   44000             Pret     CDI
# 4            5   24  Dubois  Lachaise   54400             Pret     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 1             B             1000         11.14               0
# 2             C             5500         12.87               1
# 3             C            35000         15.23               1
# 4             C            35000         14.27               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# ...

# %%
#Afficher les 5 derniers éléments
df.tail(5)
# Out:
#     Id_personne  Age       Nom  Prenom  Revenu Type de domicile  \
# 15           16   32     Petit  Prince  500000     Propriétaire
# 16           17   23   Richard  Arnaud  120000        Locataire
# 17           18   31    Tchana  Albert   92111        Locataire
# 18           19   23  Tchuente    Isis  113000        Locataire
# 19           20   24     Yemba  Elodie   10800             Pret
#
#            Travail Grade du pret  Montant du prêt  Taux_interet  \
# 15  Entreprenariat             B            30000         10.65
# 16             CDI             A            35000          7.90
# 17             CDD             F            35000         20.25
# 18  Entreprenariat             D            35000         18.25
# 19             CDD             B             1750         10.99
#
#     Statut_du_pret  Taux_endettement Défaut  Nombre de credit historique
# 15               0              0.06      N                            3
# ...

# %%
#Voir la liste des colonnes du dataframe
df.columns
# Out:
# Index(['Id_personne', 'Age', 'Nom', 'Prenom', 'Revenu', 'Type de domicile',
#        'Travail', 'Grade du pret', 'Montant du prêt', 'Taux_interet',
#        'Statut_du_pret', 'Taux_endettement', 'Défaut',
#        'Nombre de credit historique'],
#       dtype='str')

# %%
#Voir le type de données de ma base de données
df.dtypes
# Out:
# Id_personne                      int64
# Age                              int64
# Nom                                str
# Prenom                             str
# Revenu                           int64
# Type de domicile                   str
# Travail                            str
# Grade du pret                      str
# Montant du prêt                  int64
# Taux_interet                   float64
# Statut_du_pret                   int64
# Taux_endettement               float64
# Défaut                             str
# Nombre de credit historique      int64
# dtype: object

# %%
#Voir la dimension de notre tableau
df.shape
# Out:
# (20, 14)

# %% [markdown]
# **3. Lecture des tableaux pandas**

# %% [markdown]
# **3.1 Sélectionner des colonnes**

# %%
#Si la variable n'a pas d'espace
df.Id_personne.head(5)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id_personne, dtype: int64

# %%
#Si la variable à des caractères spéciaux
df["Type de domicile"].head(6)
# Out:
# 0       Locataire
# 1    Propriétaire
# 2       Locataire
# 3            Pret
# 4            Pret
# 5       Locataire
# Name: Type de domicile, dtype: str

# %%
#Sélectionner plusieurs colonnes
new_df = df[["Type de domicile", "Nom"]]
new_df.head(4)
# Out:
#   Type de domicile     Nom
# 0        Locataire   Akono
# 1     Propriétaire    Akwa
# 2        Locataire  Arnaud
# 3             Pret     Awa

# %%
#Connaitre les valeurs uniques d'une liste
df["Type de domicile"].unique()
# Out:
# <StringArray>
# ['Locataire', 'Propriétaire', 'Pret']
# Length: 3, dtype: str

# %% [markdown]
# **3.2 Selectionner des lignes**

# %%
#Sélectionner des lignes qui respectent une condition unique
new_cdi = df[df["Travail"]=="CDI"]
new_cdi.head(5)
# Out:
#    Id_personne  Age      Nom    Prenom  Revenu Type de domicile Travail  \
# 0            1   40    Akono    Nathan   59000        Locataire     CDI
# 1            2   35     Akwa     Aicha   70000     Propriétaire     CDI
# 3            4   23      Awa     Marie   44000             Pret     CDI
# 4            5   24   Dubois  Lachaise   54400             Pret     CDI
# 6            7   44  Ekounou       Eli   77100     Propriétaire     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 1             B             1000         11.14               0
# 3             C            35000         15.23               1
# 4             C            35000         14.27               1
# 6             B            35000         12.42               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# ...

# %%
#Selectionner des lignes avec plusieurs conditions
new_pret = df[(df["Travail"]=="CDI") & (df["Grade du pret"]=="D")]
new_pret.head(5)
# Out:
#    Id_personne  Age       Nom  Prenom  Revenu Type de domicile Travail  \
# 0            1   40     Akono  Nathan   59000        Locataire     CDI
# 9           10   50  Mvog-ada  Bertin   80000     Propriétaire     CDI
#
#   Grade du pret  Montant du prêt  Taux_interet  Statut_du_pret  \
# 0             D            35000         16.02               1
# 9             D             1600         14.74               1
#
#    Taux_endettement Défaut  Nombre de credit historique
# 0              0.59      Y                            3
# 9              0.16      N                            3

# %% [markdown]
# **3.3 Indexation avec iloc(index location)**

# %%
#Sélection de la première ligne
df.iloc[0]
# Out:
# Id_personne                            1
# Age                                   40
# Nom                                Akono
# Prenom                            Nathan
# Revenu                             59000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          D
# Montant du prêt                    35000
# Taux_interet                       16.02
# Statut_du_pret                         1
# Taux_endettement                    0.59
# Défaut                                 Y
# Nombre de credit historique            3
# Name: 0, dtype: object

# %%
#Sélectionner la dernière colonne
df.iloc[-1]
# Out:
# Id_personne                        20
# Age                                24
# Nom                             Yemba
# Prenom                         Elodie
# Revenu                          10800
# Type de domicile                 Pret
# Travail                           CDD
# Grade du pret                       B
# Montant du prêt                  1750
# Taux_interet                    10.99
# Statut_du_pret                      1
# Taux_endettement                 0.16
# Défaut                              N
# Nombre de credit historique         2
# Name: 19, dtype: object

# %%
#Sélectionner les deux premières lignes et les deux première colonnes
df.iloc[:2,:2]
# Out:
#    Id_personne  Age
# 0            1   40
# 1            2   35

# %% [markdown]
# **3.4 Indexation avec loc (accéder aux éléments à partir des labels)**

# %%
#Création d'un index dans le dataframe df_etudiant
#df = df.set_index("Nom")
df
df.loc["Akono"]
# Out:
# Id_personne                            1
# Age                                   40
# Prenom                            Nathan
# Revenu                             59000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          D
# Montant du prêt                    35000
# Taux_interet                       16.02
# Statut_du_pret                         1
# Taux_endettement                    0.59
# Défaut                                 Y
# Nombre de credit historique            3
# Name: Akono, dtype: object

# %%
#Sélection de la ligne Mendong
df.loc["Mendong"]
# Out:
# Id_personne                            8
# Age                                   24
# Prenom                              Zibi
# Revenu                             33000
# Type de domicile               Locataire
# Travail                              CDI
# Grade du pret                          B
# Montant du prêt                    35000
# Taux_interet                       11.11
# Statut_du_pret                         1
# Taux_endettement                    0.44
# Défaut                                 N
# Nombre de credit historique            4
# Name: Mendong, dtype: object

# %% [markdown]
# **4. Statistiques descriptives**

# %% [markdown]
# **4.1 Obtenir des statistiques de base(moyenne, médiane, écart-type)**

# %%
#Description des variables quantitatives
df.describe()
# Out:
#        Id_personne        Age         Revenu  Montant du prêt  Taux_interet  \
# count     20.00000  20.000000      20.000000        20.000000     20.000000
# mean      10.50000  28.450000   82503.550000     25092.500000     12.253500
# std        5.91608   8.274724  105576.833252     15036.274341      3.899438
# min        1.00000  21.000000    9600.000000      1000.000000      7.140000
# 25%        5.75000  23.000000   24750.000000      5250.000000      8.832500
# 50%       10.50000  24.000000   64500.000000     35000.000000     11.125000
# 75%       15.25000  32.500000   98290.000000     35000.000000     14.862500
# max       20.00000  50.000000  500000.000000     35000.000000     20.250000
#
#        Statut_du_pret  Taux_endettement  Nombre de credit historique
# count       20.000000         20.000000                    20.000000
# mean         0.800000          0.352500                     3.050000
# std          0.410391          0.154507                     0.887041
# ...

# %% [markdown]
# **4.2 Compter les valeurs uniques et les fréquences**

# %%
#Description des variables qualitatives
df.describe(include="object")
# Out:
# /var/folders/jj/mfrmmt4d5jlddtlxr2rq4n040000gn/T/ipykernel_63030/3082653242.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        Prenom Type de domicile Travail Grade du pret Défaut
# count      20               20      20            20     20
# unique     18                3       3             6      2
# top     Marie        Locataire     CDI             B      N
# freq        2               10      11             6     18

# %%
#Compter les valeurs manquantes par variable
df.isnull().mean()
# Out:
# Id_personne                    0.0
# Age                            0.0
# Prenom                         0.0
# Revenu                         0.0
# Type de domicile               0.0
# Travail                        0.0
# Grade du pret                  0.0
# Montant du prêt                0.0
# Taux_interet                   0.0
# Statut_du_pret                 0.0
# Taux_endettement               0.0
# Défaut                         0.0
# Nombre de credit historique    0.0
# dtype: float64

# %% [markdown]
# **5 Modifier les données**

# %% [markdown]
# **5.1 Suppression des lignes**

# %%
df.dropna(inplace=True)
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# **5.2 Suppression d'une colonne**

# %%
#Supprimer une colone
df.drop("Revenu",axis=1)
# Out:
#           Id_personne  Age     Prenom Type de domicile         Travail  \
# Nom
# Akono               1   40     Nathan        Locataire             CDI
# Akwa                2   35      Aicha     Propriétaire             CDI
# Arnaud              3   25      Matin        Locataire             CDD
# Awa                 4   23      Marie             Pret             CDI
# Dubois              5   24   Lachaise             Pret             CDI
# Durand              6   21     Bertin        Locataire             CDD
# Ekounou             7   44        Eli     Propriétaire             CDI
# Mendong             8   24       Zibi        Locataire             CDI
# Moussa              9   24     Hamado        Locataire             CDI
# Mvog-ada           10   50     Bertin     Propriétaire             CDI
# Mvogo              11   22    Melanie        Locataire             CDD
# Neba               12   21   Charlène        Locataire             CDD
# ...

# %% [markdown]
# **5.3 Création d'une nouvelle variable étant la multiplication de deux colonnes du tableau**

# %%
#Création d'une nouvelle variable comme étant la multiplication de deux colonnes du tableau
df["test"]=df["Montant du prêt"]*df["Taux_interet"]
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# **5.4 Mettre à jour une colonne**

# %%
#Mettre à jour avec une valeur pour toutes les lignes
df["test"]=100
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# **5.5 Mettre à jour une valeur**

# %%
#Mise à jour de la dernière colonne de la première ligne
df.iloc[0,-1]=100000
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# **5.6 Mettre à jour des valeurs qui respectent des conditions**

# %%
#Modifier la valeur de la colonne d'une ligne en fonction d'une condition (remplacer D par F)
df.loc[df["Travail"]=="CDI","Travail"]="CDD"
df
# Out:
#           Id_personne  Age     Prenom  Revenu Type de domicile  \
# Nom
# Akono               1   40     Nathan   59000        Locataire
# Akwa                2   35      Aicha   70000     Propriétaire
# Arnaud              3   25      Matin    9600        Locataire
# Awa                 4   23      Marie   44000             Pret
# Dubois              5   24   Lachaise   54400             Pret
# Durand              6   21     Bertin    9900        Locataire
# Ekounou             7   44        Eli   77100     Propriétaire
# Mendong             8   24       Zibi   33000        Locataire
# Moussa              9   24     Hamado   24000        Locataire
# Mvog-ada           10   50     Bertin   80000     Propriétaire
# Mvogo              11   22    Melanie   25000        Locataire
# Neba               12   21   Charlène   10000        Locataire
# Ngo                13   34  Stephanie   95000             Pret
# Ngono              14   26      Marie  108160             Pret
# ...

# %% [markdown]
# **6 Fusion et jointure de DataFrames**

# %%
#Création des datas frames exemple
data1 = {
    "ID":[1, 2, 3, 4],
    "Prénom": ["Alice", "Bob", "Charlie", "David"]
}
data2 = {
    "ID":[3, 4, 5, 6],
    "Ville":["Paris", "Lyon", "Marseille", "Toulouse"]
}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

#Effectuer une jointure interne(inner_join)
inner_join = df1.merge(df2, on="ID", how="inner")

#Effectuer une jointure externe(outer_join)
outer_join = df1.merge(df2, on="ID", how="outer")

#Effectuer une jointure gauche (left_join)
left_join = df1.merge(df2, on="ID", how="left")

#Effectuer une jointure droite (right_join)
right_join = df1.merge(df2, on="ID", how="right")

#Afficher les résultats
print("Inner join:")
print(inner_join)
print("\nOuter join")
print(outer_join)
print("\nLeft join")
print(left_join)
print("\nRight join")
print(right_join)
# Out:
# Inner join:
#    ID   Prénom  Ville
# 0   3  Charlie  Paris
# 1   4    David   Lyon
#
# Outer join
#    ID   Prénom      Ville
# 0   1    Alice        NaN
# 1   2      Bob        NaN
# 2   3  Charlie      Paris
# 3   4    David       Lyon
# 4   5      NaN  Marseille
# 5   6      NaN   Toulouse
#
# Left join
#    ID   Prénom  Ville
# 0   1    Alice    NaN
# 1   2      Bob    NaN
# 2   3  Charlie  Paris
# 3   4    David   Lyon
#
# Right join
#    ID   Prénom      Ville
# 0   3  Charlie      Paris
# 1   4    David       Lyon
# 2   5      NaN  Marseille
# 3   6      NaN   Toulouse

# %% [markdown]
# **7 Enregistrer la base**

# %% [markdown]
# **7.1 Enregister en CSV**

# %%
#Enregister en CSV
df.to_csv("test.csv)

# %% [markdown]
# **7.1 Enregister en CSV****7.2 Enregister en JSON**

# %%
#Exporter en fichier json
df.to_json("test.json")
